# %%
docs = ['go india',
		'india india',
		'hip hip hurray',
		'jeetega bhai jeetega india jeetega',
		'bharat mata ki jai',
		'kohli kohli',
		'sachin sachin',
		'dhoni dhoni',
		'modi ji ki jai',
		'inquilab zindabad']

# %%
from tensorflow.keras.preprocessing.text import Tokenizer
tokenizer = Tokenizer()

# %%
tokenizer.fit_on_texts(docs)

# %%
len(tokenizer.word_index)
# Out:
# 17

# %%
sequences = tokenizer.texts_to_sequences(docs)
sequences
# Out:
# [[9, 1],
#  [1, 1],
#  [3, 3, 10],
#  [2, 11, 2, 1, 2],
#  [12, 13, 4, 5],
#  [6, 6],
#  [7, 7],
#  [8, 8],
#  [14, 15, 4, 5],
#  [16, 17]]

# %%
from keras.utils import pad_sequences
sequences = pad_sequences(sequences,padding='post')
sequences
# Out:
# array([[ 9,  1,  0,  0,  0],
#        [ 1,  1,  0,  0,  0],
#        [ 3,  3, 10,  0,  0],
#        [ 2, 11,  2,  1,  2],
#        [12, 13,  4,  5,  0],
#        [ 6,  6,  0,  0,  0],
#        [ 7,  7,  0,  0,  0],
#        [ 8,  8,  0,  0,  0],
#        [14, 15,  4,  5,  0],
#        [16, 17,  0,  0,  0]], dtype=int32)

# %%
from keras import Sequential
from keras.layers import Embedding,Input

# %%
model = Sequential()
model.add(Input(shape=(5,)))
model.add(Embedding(17,output_dim=2))

model.summary()
# Out:
# Model: "sequential_8"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ embedding_7 (Embedding)         │ (None, 5, 2)           │            34 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 34 (136.00 B)
#  Trainable params: 34 (136.00 B)
#  Non-trainable params: 0 (0.00 B)

# %%
model.compile('adam','accuracy')

# %%
pred = model.predict(sequences)
print(pred)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 196ms/step
# [[[-0.00721095  0.02737434]
#   [-0.01614658  0.04098186]
#   [-0.04902959 -0.02373374]
#   [-0.04902959 -0.02373374]
#   [-0.04902959 -0.02373374]]
#
#  [[-0.01614658  0.04098186]
#   [-0.01614658  0.04098186]
#   [-0.04902959 -0.02373374]
#   [-0.04902959 -0.02373374]
#   [-0.04902959 -0.02373374]]
#
#  [[ 0.03907696 -0.02325964]
#   [ 0.03907696 -0.02325964]
#   [ 0.03556452 -0.02799355]
#   [-0.04902959 -0.02373374]
#   [-0.04902959 -0.02373374]]
#
#  [[ 0.02230592  0.03617671]
#   [-0.00363426  0.04474323]
#   [ 0.02230592  0.03617671]
#   [-0.01614658  0.04098186]
#   [ 0.02230592  0.03617671]]
#
#  [[ 0.01560053 -0.02128384]
#   [-0.00222294 -0.01640778]
#   [ 0.0407558   0.0121385 ]
#   [-0.01640116  0.04186318]
#   [-0.04902959 -0.02373374]]
#
#  [[ 0.0204456   0.00989003]
#   [ 0.0204456   0.00989003]
#   [-0.04902959 -0.02373374]
#   [-0.04902959 -0.02373374]
#   [-0.04902959 -0.02373374]]
#
#  [[ 0.00037896 -0.02617395]
#   [ 0.00037896 -0.02617395]
#   [-0.04902959 -0.02373374]
#   [-0.04902959 -0.02373374]
#   [-0.04902959 -0.02373374]]
#
#  [[-0.04766497 -0.00929736]
#   [-0.04766497 -0.00929736]
#   [-0.04902959 -0.02373374]
#   [-0.04902959 -0.02373374]
#   [-0.04902959 -0.02373374]]
#
#  [[ 0.02504805 -0.00960718]
#   [-0.0482509   0.04220367]
#   [ 0.0407558   0.0121385 ]
#   [-0.01640116  0.04186318]
#   [-0.04902959 -0.02373374]]
#
#  [[ 0.03775683 -0.01033902]
#   [ 0.03775683 -0.01033902]
#   [-0.04902959 -0.02373374]
#   [-0.04902959 -0.02373374]
#   [-0.04902959 -0.02373374]]]

# %%
from keras.datasets import imdb
from tensorflow.keras.preprocessing.text import Tokenizer
from keras.utils import pad_sequences
from keras import Sequential
from keras.layers import Dense,SimpleRNN,Embedding,Flatten

# %%
(X_train,y_train),(X_test,y_test) = imdb.load_data()

# %%
X_train = pad_sequences(X_train,padding='post')
X_test = pad_sequences(X_test,padding='post')

# %%
X_train.shape
# Out:
# (25000, 2494)

# %%
model = Sequential()
model.add(Input(shape=(2494,)))
model.add(Embedding(10000, 2))
model.add(SimpleRNN(32,return_sequences=False))
model.add(Dense(1, activation='sigmoid'))

model.summary()
# Out:
# Model: "sequential_18"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ embedding_17 (Embedding)        │ (None, 2494, 2)        │        20,000 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ simple_rnn_7 (SimpleRNN)        │ (None, 32)             │         1,120 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_7 (Dense)                 │ (None, 1)              │            33 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 21,153 (82.63 KB)
#  Trainable params: 21,153 (82.63 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['acc'])
history = model.fit(X_train, y_train,epochs=5,validation_data=(X_test,y_test))
# Out:
# Epoch 1/5
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 139s 175ms/step - acc: 0.5016 - loss: 0.6936 - val_acc: 0.4982 - val_loss: 0.6934
# Epoch 2/5
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 135s 173ms/step - acc: 0.5015 - loss: 0.6953 - val_acc: 0.5000 - val_loss: 0.6934
# Epoch 3/5
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 135s 172ms/step - acc: 0.4954 - loss: 0.6944 - val_acc: 0.5001 - val_loss: 0.6963
# Epoch 4/5
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 135s 173ms/step - acc: 0.5070 - loss: 0.6938 - val_acc: 0.5001 - val_loss: 0.7066
# Epoch 5/5
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 135s 172ms/step - acc: 0.4998 - loss: 0.6939 - val_acc: 0.5001 - val_loss: 0.7220
